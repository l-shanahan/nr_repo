# %% [markdown]
# # Hyperparameter Optimisation

# %% [markdown]
# ### Creating smaller dataset

# %%
import tensorflow as tf
from os import listdir
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D, LeakyReLU, Dropout

# %%
def data_gen(file_nums, load_dir = '/vols/lz/lshanahan/data/numpy_noise/'):
    for i in file_nums: 
        data = np.expand_dims(np.load(f'{load_dir}/data_{i}.npy'),-1)
        labels = np.load(f'{load_dir}/labels_{i}.npy').astype(np.int32)
        for j in range(len(labels)):
            yield data[j], labels[j:j+1]
            
            
def data_gen_stack(file_nums, file_type_list, sqrt_scale= None, load_dir = '/vols/lz/lshanahan/data/numpy_noise/'):
    if sqrt_scale == None:
        sqrt_scale = [0 for f in file_type_list]
    for i in file_nums: 
        data = np.stack([np.sqrt(np.load(f'{load_dir}/data_{i}_noise'+f.decode('utf-8')+'.npy')) if s \
                               else np.load(f'{load_dir}/data_{i}_noise'+f.decode('utf-8')+'.npy') \
                               for f,s in zip(file_type_list,sqrt_scale)],axis=-1)
        labels = np.load(f'{load_dir}/labels_{i}.npy').astype(np.int32)
        for j in range(len(labels)):
            yield data[j,:,:,:], labels[j:j+1]

# %%
def opt_model(file_type_list):
    opt_model = Sequential([
        Conv2D(10, kernel_size=(3,3), input_shape=(184,184,len(file_type_list)), padding='same'),
        LeakyReLU(),
        MaxPooling2D(),
        Conv2D(30, kernel_size=(3,3), padding='same'),
        LeakyReLU(),
        MaxPooling2D(),
        Conv2D(30, kernel_size=(3,3), padding='same'),
        LeakyReLU(),
        MaxPooling2D(),
        Flatten(),
        Dropout(0.05),
        Dense(20, kernel_regularizer = tf.keras.regularizers.L1L2(0.05,0.1)),
        LeakyReLU(),
        Dropout(0.05),
        Dense(10, kernel_regularizer = tf.keras.regularizers.L1L2(0.05,0.1)),
        LeakyReLU(),
        Dense(1, activation='sigmoid'),
    ], name='opt_model')
    return opt_model

# %%
def data_train():
    
    file_nums = list(range(36))
    file_type_list = ['_0.0_threshold', '_2.0_threshold', '_4.0_threshold',]
    sqrt_scale = [0,1,0]
    print(file_type_list)
    np.random.shuffle(file_nums)
    train_dataset = tf.data.Dataset.from_generator(data_gen_stack, 
                                            args = (file_nums[:2], file_type_list, sqrt_scale),
                                            output_shapes=(tf.TensorShape((184,184,len(file_type_list))),tf.TensorShape(1)), 
                                            output_types=(tf.float64,tf.int32))

    train_data_batch = train_dataset.batch(50)

    test_dataset = tf.data.Dataset.from_generator(data_gen_stack, 
                                            args = (file_nums[2:3], file_type_list, sqrt_scale),
                                            output_shapes=(tf.TensorShape((184,184,len(file_type_list))),tf.TensorShape(1)), 
                                            output_types=(tf.float64,tf.int32))

    test_data_batch = test_dataset.batch(50)
    
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', restore_best_weights=True, patience=15)

    model = opt_model(file_type_list)

    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=opt, loss='binary_crossentropy',metrics=['accuracy'])
    model.fit(train_data_batch, epochs=150, validation_data=test_data_batch,callbacks=[callback],\
             verbose = 1)

# %%
def data_train():
    
    file_type_list = ['_0.0_threshold', '_0.0_threshold', '_4.0_threshold']
    sqrt_scale = [0,1,0]
    
    file_nums = list(range(36))
    np.random.shuffle(file_nums)
    train_dataset = tf.data.Dataset.from_generator(data_gen_stack, 
                                            args = (file_nums[:2], file_type_list, sqrt_scale),
                                            output_shapes=(tf.TensorShape((184,184,len(file_type_list))),tf.TensorShape(1)), 
                                            output_types=(tf.float64,tf.int32))

    train_data_batch = train_dataset.batch(50)

    test_dataset = tf.data.Dataset.from_generator(data_gen_stack, 
                                            args = (file_nums[2:3], file_type_list, sqrt_scale),
                                            output_shapes=(tf.TensorShape((184,184,len(file_type_list))),tf.TensorShape(1)), 
                                            output_types=(tf.float64,tf.int32))

    test_data_batch = test_dataset.batch(50)
    
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', restore_best_weights=True, patience=15)

    model = opt_model(file_type_list)

    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=opt, loss='binary_crossentropy',metrics=['accuracy'])
    model.fit(train_data_batch, epochs=150, validation_data=test_data_batch,callbacks=[callback],\
             verbose = 0)
    
#     cut = 0.1
    
#     for tdn in test_dataset_batch:
#         data, labels = tdn
#         labels = labels.numpy().flatten()
#         batch_probs = model(data).numpy().flatten()
#         indices = np.where(batch_probs < cut)[0]
#         actual_label.extend(list(labels[indices]))
#         migdals += len(labels[labels == 0])

#         fp_indices.extend(list(np.where((batch_probs < cut) & (labels == 1))[0] + total))

#         total += len(labels)

#     test_list = [x for x in actual_label if x == 0]
#     del data, labels, batch_probs, indices
#     print('With file_type_list of: '+str(file_type_list)+' and sqrt_scale of: '+str(sqrt_scale))
#     print(f'Percentage of Migdal events identified correctly: {(100*len(test_list)/migdals):.3f}%')
#     print('Number of false positive Migdal events: '+str(len(actual_label)-len(test_list)))
#     print(f'False-positive rate: {(100*(len(actual_label)-len(test_list))/(total-migdals)):.3g}%')
#     print()

# %%
data_train()
# Out:
# ['_0.0_threshold', '_2.0_threshold', '_4.0_threshold']
# Epoch 1/150
# 2022-08-11 10:49:09.643460: W tensorflow/core/framework/op_kernel.cc:1751] Invalid argument: ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Traceback (most recent call last):
#
#   File "/vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/ops/script_ops.py", line 249, in __call__
#     ret = func(*args)
#
#   File "/vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py", line 620, in wrapper
#     return func(*args, **kwargs)
#
#   File "/vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 891, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "/tmp/ipykernel_14340/3906209123.py", line 10, in data_gen_stack
#     if sqrt_scale == None:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 data_train()
#
# Input In [46], in data_train()
#      26 opt = tf.keras.optimizers.Adam(learning_rate=0.001)
#      27 model.compile(optimizer=opt, loss='binary_crossentropy',metrics=['accuracy'])
# ---> 28 model.fit(train_data_batch, epochs=150, validation_data=test_data_batch,callbacks=[callback],\
#      29          verbose = 1)
#
# File /vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1100, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1093 with trace.Trace(
#    1094     'train',
#    1095     epoch_num=epoch,
#    1096     step_num=step,
#    1097     batch_size=batch_size,
#    1098     _r=1):
#    1099   callbacks.on_train_batch_begin(step)
# -> 1100   tmp_logs = self.train_function(iterator)
#    1101   if data_handler.should_sync:
#    1102     context.async_wait()
#
# File /vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:828, in Function.__call__(self, *args, **kwds)
#     826 tracing_count = self.experimental_get_tracing_count()
#     827 with trace.Trace(self._name) as tm:
# --> 828   result = self._call(*args, **kwds)
#     829   compiler = "xla" if self._experimental_compile else "nonXla"
#     830   new_tracing_count = self.experimental_get_tracing_count()
#
# File /vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:888, in Function._call(self, *args, **kwds)
#     884     pass  # Fall through to cond-based initialization.
#     885   else:
#     886     # Lifting succeeded, so variables are initialized and we can run the
#     887     # stateless function.
# --> 888     return self._stateless_fn(*args, **kwds)
#     889 else:
#     890   _, _, _, filtered_flat_args = \
#     891       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     892           *args, **kwds)
#
# File /vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2942, in Function.__call__(self, *args, **kwargs)
#    2939 with self._lock:
#    2940   (graph_function,
#    2941    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942 return graph_function._call_flat(
#    2943     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File /vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1918, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1914 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1915 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1916     and executing_eagerly):
#    1917   # No tape is watching; skip to running the function.
# -> 1918   return self._build_call_outputs(self._inference_function.call(
#    1919       ctx, args, cancellation_manager=cancellation_manager))
#    1920 forward_backward = self._select_forward_and_backward_functions(
#    1921     args,
#    1922     possible_gradient_type,
#    1923     executing_eagerly)
#    1924 forward_function, args_with_tangents = forward_backward.forward()
#
# File /vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/eager/function.py:555, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     553 with _InterpolateFunctionError(self):
#     554   if cancellation_manager is None:
# --> 555     outputs = execute.execute(
#     556         str(self.signature.name),
#     557         num_outputs=self._num_outputs,
#     558         inputs=args,
#     559         attrs=attrs,
#     560         ctx=ctx)
#     561   else:
#     562     outputs = execute.execute_with_cancellation(
#     563         str(self.signature.name),
#     564         num_outputs=self._num_outputs,
#    (...)
#     567         ctx=ctx,
#     568         cancellation_manager=cancellation_manager)
#
# File /vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57 try:
#      58   ctx.ensure_initialized()
# ---> 59   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                       inputs, attrs, num_outputs)
#      61 except core._NotOkStatusException as e:
#      62   if name is not None:
#
# InvalidArgumentError: 2 root error(s) found.
#   (0) Invalid argument:  ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Traceback (most recent call last):
#
#   File "/vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/ops/script_ops.py", line 249, in __call__
#     ret = func(*args)
#
#   File "/vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py", line 620, in wrapper
#     return func(*args, **kwargs)
#
#   File "/vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 891, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "/tmp/ipykernel_14340/3906209123.py", line 10, in data_gen_stack
#     if sqrt_scale == None:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
#   (1) Invalid argument:  ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# Traceback (most recent call last):
#
#   File "/vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/ops/script_ops.py", line 249, in __call__
#     ret = func(*args)
#
#   File "/vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py", line 620, in wrapper
#     return func(*args, **kwargs)
#
#   File "/vols/lz/MIGDAL/home/hep/lms121/vols/lz/MIGDAL/Anaconda/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py", line 891, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "/tmp/ipykernel_14340/3906209123.py", line 10, in data_gen_stack
#     if sqrt_scale == None:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
# 	 [[Shape/_6]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_15858]
#
# Function call stack:
# train_function -> train_function

# %%
file_types = ['','sqrt_sub_bg','_0.0_threshold','_1.0_threshold','_2.0_threshold','_3.0_threshold',\
             '_4.0_threshold','_5.0_threshold']

for i in file_types:
    print(i)
    
from itertools import chain, combinations

def powerset(iterable):
    return chain.from_iterable(combinations(file_types, r) for r in range(len(file_types)+1))

stuff = [1, 2, 3]
for i, combo in enumerate(powerset(stuff), 1):
    print('combo #{}: {}'.format(i, combo))
# Out:
# sqrt_sub_bg
# _0.0_threshold
# _1.0_threshold
# _2.0_threshold
# _3.0_threshold
# _4.0_threshold
# _5.0_threshold
# combo #1: ()
# combo #2: ('',)
# combo #3: ('sqrt_sub_bg',)
# combo #4: ('_0.0_threshold',)
# combo #5: ('_1.0_threshold',)
# combo #6: ('_2.0_threshold',)
# combo #7: ('_3.0_threshold',)
# combo #8: ('_4.0_threshold',)
# combo #9: ('_5.0_threshold',)
# combo #10: ('', 'sqrt_sub_bg')
# combo #11: ('', '_0.0_threshold')
# combo #12: ('', '_1.0_threshold')
# combo #13: ('', '_2.0_threshold')
# combo #14: ('', '_3.0_threshold')
# combo #15: ('', '_4.0_threshold')
# combo #16: ('', '_5.0_threshold')
# combo #17: ('sqrt_sub_bg', '_0.0_threshold')
# combo #18: ('sqrt_sub_bg', '_1.0_threshold')
# combo #19: ('sqrt_sub_bg', '_2.0_threshold')
# combo #20: ('sqrt_sub_bg', '_3.0_threshold')
# combo #21: ('sqrt_sub_bg', '_4.0_threshold')
# combo #22: ('sqrt_sub_bg', '_5.0_threshold')
# combo #23: ('_0.0_threshold', '_1.0_threshold')
# combo #24: ('_0.0_threshold', '_2.0_threshold')
# combo #25: ('_0.0_threshold', '_3.0_threshold')
# combo #26: ('_0.0_threshold', '_4.0_threshold')
# combo #27: ('_0.0_threshold', '_5.0_threshold')
# combo #28: ('_1.0_threshold', '_2.0_threshold')
# combo #29: ('_1.0_threshold', '_3.0_threshold')
# combo #30: ('_1.0_threshold', '_4.0_threshold')
# combo #31: ('_1.0_threshold', '_5.0_threshold')
# combo #32: ('_2.0_threshold', '_3.0_threshold')
# combo #33: ('_2.0_threshold', '_4.0_threshold')
# combo #34: ('_2.0_threshold', '_5.0_threshold')
# combo #35: ('_3.0_threshold', '_4.0_threshold')
# combo #36: ('_3.0_threshold', '_5.0_threshold')
# combo #37: ('_4.0_threshold', '_5.0_threshold')
# combo #38: ('', 'sqrt_sub_bg', '_0.0_threshold')
# combo #39: ('', 'sqrt_sub_bg', '_1.0_threshold')
# combo #40: ('', 'sqrt_sub_bg', '_2.0_threshold')
# combo #41: ('', 'sqrt_sub_bg', '_3.0_threshold')
# combo #42: ('', 'sqrt_sub_bg', '_4.0_threshold')
# combo #43: ('', 'sqrt_sub_bg', '_5.0_threshold')
# combo #44: ('', '_0.0_threshold', '_1.0_threshold')
# combo #45: ('', '_0.0_threshold', '_2.0_threshold')
# combo #46: ('', '_0.0_threshold', '_3.0_threshold')
# combo #47: ('', '_0.0_threshold', '_4.0_threshold')
# combo #48: ('', '_0.0_threshold', '_5.0_threshold')
# combo #49: ('', '_1.0_threshold', '_2.0_threshold')
# combo #50: ('', '_1.0_threshold', '_3.0_threshold')
# combo #51: ('', '_1.0_threshold', '_4.0_threshold')
# combo #52: ('', '_1.0_threshold', '_5.0_threshold')
# combo #53: ('', '_2.0_threshold', '_3.0_threshold')
# combo #54: ('', '_2.0_threshold', '_4.0_threshold')
# combo #55: ('', '_2.0_threshold', '_5.0_threshold')
# combo #56: ('', '_3.0_threshold', '_4.0_threshold')
# combo #57: ('', '_3.0_threshold', '_5.0_threshold')
# combo #58: ('', '_4.0_threshold', '_5.0_threshold')
# combo #59: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold')
# combo #60: ('sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold')
# combo #61: ('sqrt_sub_bg', '_0.0_threshold', '_3.0_threshold')
# combo #62: ('sqrt_sub_bg', '_0.0_threshold', '_4.0_threshold')
# combo #63: ('sqrt_sub_bg', '_0.0_threshold', '_5.0_threshold')
# combo #64: ('sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold')
# combo #65: ('sqrt_sub_bg', '_1.0_threshold', '_3.0_threshold')
# combo #66: ('sqrt_sub_bg', '_1.0_threshold', '_4.0_threshold')
# combo #67: ('sqrt_sub_bg', '_1.0_threshold', '_5.0_threshold')
# combo #68: ('sqrt_sub_bg', '_2.0_threshold', '_3.0_threshold')
# combo #69: ('sqrt_sub_bg', '_2.0_threshold', '_4.0_threshold')
# combo #70: ('sqrt_sub_bg', '_2.0_threshold', '_5.0_threshold')
# combo #71: ('sqrt_sub_bg', '_3.0_threshold', '_4.0_threshold')
# combo #72: ('sqrt_sub_bg', '_3.0_threshold', '_5.0_threshold')
# combo #73: ('sqrt_sub_bg', '_4.0_threshold', '_5.0_threshold')
# combo #74: ('_0.0_threshold', '_1.0_threshold', '_2.0_threshold')
# combo #75: ('_0.0_threshold', '_1.0_threshold', '_3.0_threshold')
# combo #76: ('_0.0_threshold', '_1.0_threshold', '_4.0_threshold')
# combo #77: ('_0.0_threshold', '_1.0_threshold', '_5.0_threshold')
# combo #78: ('_0.0_threshold', '_2.0_threshold', '_3.0_threshold')
# combo #79: ('_0.0_threshold', '_2.0_threshold', '_4.0_threshold')
# combo #80: ('_0.0_threshold', '_2.0_threshold', '_5.0_threshold')
# combo #81: ('_0.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #82: ('_0.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #83: ('_0.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #84: ('_1.0_threshold', '_2.0_threshold', '_3.0_threshold')
# combo #85: ('_1.0_threshold', '_2.0_threshold', '_4.0_threshold')
# combo #86: ('_1.0_threshold', '_2.0_threshold', '_5.0_threshold')
# combo #87: ('_1.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #88: ('_1.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #89: ('_1.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #90: ('_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #91: ('_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #92: ('_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #93: ('_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #94: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold')
# combo #95: ('', 'sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold')
# combo #96: ('', 'sqrt_sub_bg', '_0.0_threshold', '_3.0_threshold')
# combo #97: ('', 'sqrt_sub_bg', '_0.0_threshold', '_4.0_threshold')
# combo #98: ('', 'sqrt_sub_bg', '_0.0_threshold', '_5.0_threshold')
# combo #99: ('', 'sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold')
# combo #100: ('', 'sqrt_sub_bg', '_1.0_threshold', '_3.0_threshold')
# combo #101: ('', 'sqrt_sub_bg', '_1.0_threshold', '_4.0_threshold')
# combo #102: ('', 'sqrt_sub_bg', '_1.0_threshold', '_5.0_threshold')
# combo #103: ('', 'sqrt_sub_bg', '_2.0_threshold', '_3.0_threshold')
# combo #104: ('', 'sqrt_sub_bg', '_2.0_threshold', '_4.0_threshold')
# combo #105: ('', 'sqrt_sub_bg', '_2.0_threshold', '_5.0_threshold')
# combo #106: ('', 'sqrt_sub_bg', '_3.0_threshold', '_4.0_threshold')
# combo #107: ('', 'sqrt_sub_bg', '_3.0_threshold', '_5.0_threshold')
# combo #108: ('', 'sqrt_sub_bg', '_4.0_threshold', '_5.0_threshold')
# combo #109: ('', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold')
# combo #110: ('', '_0.0_threshold', '_1.0_threshold', '_3.0_threshold')
# combo #111: ('', '_0.0_threshold', '_1.0_threshold', '_4.0_threshold')
# combo #112: ('', '_0.0_threshold', '_1.0_threshold', '_5.0_threshold')
# combo #113: ('', '_0.0_threshold', '_2.0_threshold', '_3.0_threshold')
# combo #114: ('', '_0.0_threshold', '_2.0_threshold', '_4.0_threshold')
# combo #115: ('', '_0.0_threshold', '_2.0_threshold', '_5.0_threshold')
# combo #116: ('', '_0.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #117: ('', '_0.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #118: ('', '_0.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #119: ('', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold')
# combo #120: ('', '_1.0_threshold', '_2.0_threshold', '_4.0_threshold')
# combo #121: ('', '_1.0_threshold', '_2.0_threshold', '_5.0_threshold')
# combo #122: ('', '_1.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #123: ('', '_1.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #124: ('', '_1.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #125: ('', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #126: ('', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #127: ('', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #128: ('', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #129: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold')
# combo #130: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_3.0_threshold')
# combo #131: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_4.0_threshold')
# combo #132: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_5.0_threshold')
# combo #133: ('sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold', '_3.0_threshold')
# combo #134: ('sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold', '_4.0_threshold')
# combo #135: ('sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold', '_5.0_threshold')
# combo #136: ('sqrt_sub_bg', '_0.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #137: ('sqrt_sub_bg', '_0.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #138: ('sqrt_sub_bg', '_0.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #139: ('sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold')
# combo #140: ('sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold', '_4.0_threshold')
# combo #141: ('sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold', '_5.0_threshold')
# combo #142: ('sqrt_sub_bg', '_1.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #143: ('sqrt_sub_bg', '_1.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #144: ('sqrt_sub_bg', '_1.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #145: ('sqrt_sub_bg', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #146: ('sqrt_sub_bg', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #147: ('sqrt_sub_bg', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #148: ('sqrt_sub_bg', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #149: ('_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold')
# combo #150: ('_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_4.0_threshold')
# combo #151: ('_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_5.0_threshold')
# combo #152: ('_0.0_threshold', '_1.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #153: ('_0.0_threshold', '_1.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #154: ('_0.0_threshold', '_1.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #155: ('_0.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #156: ('_0.0_threshold', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #157: ('_0.0_threshold', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #158: ('_0.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #159: ('_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #160: ('_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #161: ('_1.0_threshold', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #162: ('_1.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #163: ('_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #164: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold')
# combo #165: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_3.0_threshold')
# combo #166: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_4.0_threshold')
# combo #167: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_5.0_threshold')
# combo #168: ('', 'sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold', '_3.0_threshold')
# combo #169: ('', 'sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold', '_4.0_threshold')
# combo #170: ('', 'sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold', '_5.0_threshold')
# combo #171: ('', 'sqrt_sub_bg', '_0.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #172: ('', 'sqrt_sub_bg', '_0.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #173: ('', 'sqrt_sub_bg', '_0.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #174: ('', 'sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold')
# combo #175: ('', 'sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold', '_4.0_threshold')
# combo #176: ('', 'sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold', '_5.0_threshold')
# combo #177: ('', 'sqrt_sub_bg', '_1.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #178: ('', 'sqrt_sub_bg', '_1.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #179: ('', 'sqrt_sub_bg', '_1.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #180: ('', 'sqrt_sub_bg', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #181: ('', 'sqrt_sub_bg', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #182: ('', 'sqrt_sub_bg', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #183: ('', 'sqrt_sub_bg', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #184: ('', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold')
# combo #185: ('', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_4.0_threshold')
# combo #186: ('', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_5.0_threshold')
# combo #187: ('', '_0.0_threshold', '_1.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #188: ('', '_0.0_threshold', '_1.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #189: ('', '_0.0_threshold', '_1.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #190: ('', '_0.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #191: ('', '_0.0_threshold', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #192: ('', '_0.0_threshold', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #193: ('', '_0.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #194: ('', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #195: ('', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #196: ('', '_1.0_threshold', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #197: ('', '_1.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #198: ('', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #199: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold')
# combo #200: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_4.0_threshold')
# combo #201: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_5.0_threshold')
# combo #202: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #203: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #204: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #205: ('sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #206: ('sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #207: ('sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #208: ('sqrt_sub_bg', '_0.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #209: ('sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #210: ('sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #211: ('sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #212: ('sqrt_sub_bg', '_1.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #213: ('sqrt_sub_bg', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #214: ('_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #215: ('_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #216: ('_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #217: ('_0.0_threshold', '_1.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #218: ('_0.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #219: ('_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #220: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold')
# combo #221: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_4.0_threshold')
# combo #222: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_5.0_threshold')
# combo #223: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #224: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #225: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #226: ('', 'sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #227: ('', 'sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #228: ('', 'sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #229: ('', 'sqrt_sub_bg', '_0.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #230: ('', 'sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #231: ('', 'sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #232: ('', 'sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #233: ('', 'sqrt_sub_bg', '_1.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #234: ('', 'sqrt_sub_bg', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #235: ('', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #236: ('', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #237: ('', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #238: ('', '_0.0_threshold', '_1.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #239: ('', '_0.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #240: ('', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #241: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #242: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #243: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #244: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #245: ('sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #246: ('sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #247: ('_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #248: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold')
# combo #249: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_5.0_threshold')
# combo #250: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #251: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #252: ('', 'sqrt_sub_bg', '_0.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #253: ('', 'sqrt_sub_bg', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #254: ('', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #255: ('sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
# combo #256: ('', 'sqrt_sub_bg', '_0.0_threshold', '_1.0_threshold', '_2.0_threshold', '_3.0_threshold', '_4.0_threshold', '_5.0_threshold')
